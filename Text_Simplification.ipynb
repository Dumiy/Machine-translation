# %%
# !git clone https://github.com/facebookresearch/muss
# !pip install -e /content/muss/.  # Install package
# !python -m spacy download en_core_web_md 
# !python -m spacy download fr_core_news_md
# !python -m spacy download es_core_news_md
# Out:
# Cloning into 'muss'...
# remote: Enumerating objects: 395, done.
# remote: Counting objects: 100% (395/395), done.
# remote: Compressing objects: 100% (235/235), done.
# remote: Total 395 (delta 188), reused 354 (delta 158), pack-reused 0
# Receiving objects: 100% (395/395), 5.38 MiB | 15.30 MiB/s, done.
# Resolving deltas: 100% (188/188), done.
# Obtaining file:///content/muss
# ...
#   Cloning git://github.com/feralvam/easse.git to /tmp/pip-install-8lq3yxl6/easse_e9bf8cdfc189431d8f5774d3bab1c4af
#   Running command git clone -q git://github.com/feralvam/easse.git /tmp/pip-install-8lq3yxl6/easse_e9bf8cdfc189431d8f5774d3bab1c4af
# ...
#   Cloning git://github.com/kpu/kenlm.git to /tmp/pip-install-8lq3yxl6/kenlm_37543c2d951a4b198fac828b2d0217b8
#   Running command git clone -q git://github.com/kpu/kenlm.git /tmp/pip-install-8lq3yxl6/kenlm_37543c2d951a4b198fac828b2d0217b8
# ...
#      |████████████████████████████████| 1.5 MB 14.9 MB/s
# ...
#      |████████████████████████████████| 180 kB 56.5 MB/s
# ...

# %%
# !python /content/muss/scripts/simplify.py /content/muss/scripts/examples.en --model-name muss_en_wikilarge_mined
# Out:
# Downloading...
# ... 100% - 3835 MB - 35.80 MB/s - 107s
# Extracting...
# Downloading...
# ... 100% - 1 MB - 20.58 MB/s - 0s
# Downloading...
# ... 100% - 0 MB - 14.77 MB/s - 0s
# Downloading...
# ... 100% - 0 MB - 13.88 MB/s - 0s
# tcmalloc: large alloc 1625161728 bytes == 0x562edbc1e000 @  0x7f835a043b6b 0x7f835a063379 0x7f823acb3cde 0x7f823acb5452 0x7f828d727749 0x7f8336550d59 0x562e66da3045 0x562e66d63c52 0x562e66dd6c25 0x562e66dd1ced 0x562e66d647f3 0x562e66d642f9 0x562e66eab35d 0x562e66e1aa0b 0x562e66d633a1 0x562e66e54e1d 0x562e66dd6e99 0x562e66dd1ced 0x562e66ca3e2b 0x562e66dd3fe4 0x562e66dd19ee 0x562e66d64bda 0x562e66dd3737 0x562e66dd19ee 0x562e66d64bda 0x562e66dd2915 0x562e66dd19ee 0x562e66d64bda 0x562e66dd2915 0x562e66dd19ee 0x562e66d64bda
# ...

# %%
# !python /content/muss/scripts/train_model.py
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 006 | valid on 'valid' subset:   5% 270/5149 [00:09<03:06, 26.23it/s]
# epoch 006 | valid on 'valid' subset:   5% 273/5149 [00:10<03:14, 25.12it/s]
# epoch 006 | valid on 'valid' subset:   5% 276/5149 [00:10<03:16, 24.79it/s]
# epoch 006 | valid on 'valid' subset:   5% 279/5149 [00:10<03:15, 24.91it/s]
# epoch 006 | valid on 'valid' subset:   5% 282/5149 [00:10<03:09, 25.64it/s]
# epoch 006 | valid on 'valid' subset:   6% 285/5149 [00:10<03:04, 26.30it/s]
# epoch 006 | valid on 'valid' subset:   6% 288/5149 [00:10<03:09, 25.70it/s]
# epoch 006 | valid on 'valid' subset:   6% 291/5149 [00:10<03:06, 26.11it/s]
# epoch 006 | valid on 'valid' subset:   6% 294/5149 [00:10<03:05, 26.22it/s]
# epoch 006 | valid on 'valid' subset:   6% 297/5149 [00:11<03:03, 26.46it/s]
# epoch 006 | valid on 'valid' subset:   6% 300/5149 [00:11<03:03, 26.42it/s]
# epoch 006 | valid on 'valid' subset:   6% 303/5149 [00:11<03:00, 26.91it/s]
# ...
